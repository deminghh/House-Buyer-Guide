# %%
import requests
import os
import pandas as pd
import json
from cred import credentials
import numpy as np

from request_api import get_genesis_api

# %%
df_building_completions= get_genesis_api('31121-0002', [2008])
df_building_completions
# Out:
#     Unnamed: 0_level_0                                 Unnamed: 1_level_0  \
#     Unnamed: 0_level_1                                 Unnamed: 1_level_1
# 0    Baden-Württemberg          Residential and non-residential buildings
# 1    Baden-Württemberg                              Residential buildings
# 2    Baden-Württemberg              Residential buildings with 1 dwelling
# 3    Baden-Württemberg             Residential buildings with 2 dwellings
# 4    Baden-Württemberg        Residential buildings with 1 or 2 dwellings
# ..                 ...                                                ...
# 555          Thüringen       Households as builders of non-res. buildings
# 556          Thüringen  Non-profit inst. as builders of non-res. build...
# 557          Thüringen  Pub.builders,non-prof.inst.as build.of non-res.b.
# 558          Thüringen   Non-public builders of non-residential buildings
# 559          Thüringen  Selected infrastr. buildings (non-res. buildings)
#
#     Unnamed: 2_level_0 Buildings / reconstruction projects Buildings  \
#     Unnamed: 2_level_1                              number    number
# 0                 2008                               28663         -
# 1                 2008                               20935         -
# 2                 2008                                   x         x
# 3                 2008                                   x         x
# 4                 2008                                   x         x
# ..                 ...                                 ...       ...
# 555               2008                                 395         -
# 556               2008                                  66         -
# 557               2008                                 235         -
# 558               2008                                1147         -
# 559               2008                                 244         -
#
#     Volume constructed Construction projects Useful floor space Dwellings  \
#               1000 cbm                number            1000 qm    number
# 0                    -                     -               6231     27587
# 1                    -                     -               1008     26854
# 2                    x                     x                  x         x
# 3                    x                     x                  x         x
# 4                    x                     x                  x         x
# ..                 ...                   ...                ...       ...
# 555                  -                     -                 38        55
# 556                  -                     -                 44         6
# 557                  -                     -                 98        14
# 558                  -                     -                675       117
# 559                  -                     -                124        10
#
#     Living floor space of dwellings  ... Buildings Volume constructed  \
#                             1000 qm  ...  number.2         1000 cbm.2
# 0                              3346  ...         -                  -
# 1                              3269  ...         -                  -
# 2                                 x  ...         -                  -
# 3                                 x  ...         -                  -
# 4                                 x  ...         -                  -
# ..                              ...  ...       ...                ...
# 555                               5  ...         -                  -
# 556                               0  ...         -                  -
# 557                               0  ...         -                  -
# 558                              10  ...         -                  -
# 559                               0  ...         -                  -
#
#     Construction projects Useful floor space Dwellings  \
#                  number.2          1000 qm.2  number.2
# 0                   11296                744      2804
# 1                    7793                -94      2693
# 2                       x                  x         x
# 3                       x                  x         x
# 4                       x                  x         x
# ..                    ...                ...       ...
# 555                   178                  5        46
# 556                    35                  5         6
# 557                   138                  9        14
# 558                   456                 99        66
# 559                   142                  9        10
#
#     Living floor space of dwellings Other housing units  \
#                           1000 qm.2            number.2
# 0                               469                -421
# 1                               452                -275
# 2                                 x                   x
# 3                                 x                   x
# 4                                 x                   x
# ..                              ...                 ...
# 555                               4                   -
# 556                               0                 -15
# 557                               0                 -15
# 558                               6                   -
# 559                               0                 -15
#
#     Living floor space of other housing units    Rooms  \
#                                     1000 qm.2 number.2
# 0                                          -8    15266
# 1                                          -5    15113
# 2                                           x        x
# 3                                           x        x
# 4                                           x        x
# ..                                        ...      ...
# 555                                         -      160
# 556                                         0      -18
# 557                                         0       -8
# 558                                         -      229
# 559                                         0       -3
#
#     Estimated costs of the construction
#                              Tsd. EUR.2
# 0                               1963624
# 1                                707630
# 2                                     x
# 3                                     x
# 4                                     x
# ..                                  ...
# 555                               16325
# 556                               13964
# 557                               94055
# 558                               96985
# 559                               76657
#
# [560 rows x 36 columns]

# %%
df_building_completions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 560 entries, 0 to 559
# Data columns (total 36 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   (Unnamed: 0_level_0, Unnamed: 0_level_1)                560 non-null    object
#  1   (Unnamed: 1_level_0, Unnamed: 1_level_1)                560 non-null    object
#  2   (Unnamed: 2_level_0, Unnamed: 2_level_1)                560 non-null    int64
#  3   (Buildings / reconstruction projects, number)           560 non-null    object
#  4   (Buildings, number)                                     560 non-null    object
#  5   (Volume constructed, 1000 cbm)                          560 non-null    object
#  6   (Construction projects, number)                         560 non-null    object
#  7   (Useful floor space, 1000 qm)                           560 non-null    object
#  8   (Dwellings, number)                                     560 non-null    object
#  9   (Living floor space of dwellings, 1000 qm)              560 non-null    object
#  10  (Other housing units, number)                           560 non-null    object
#  11  (Living floor space of other housing units, 1000 qm)    560 non-null    object
#  12  (Rooms, number)                                         560 non-null    object
#  13  (Estimated costs of the construction, Tsd. EUR)         560 non-null    object
#  14  (Buildings / reconstruction projects, number.1)         560 non-null    object
#  15  (Buildings, number.1)                                   560 non-null    object
#  16  (Volume constructed, 1000 cbm.1)                        560 non-null    object
#  17  (Construction projects, number.1)                       560 non-null    object
#  18  (Useful floor space, 1000 qm.1)                         560 non-null    object
#  19  (Dwellings, number.1)                                   560 non-null    object
#  20  (Living floor space of dwellings, 1000 qm.1)            560 non-null    object
#  21  (Other housing units, number.1)                         560 non-null    object
#  22  (Living floor space of other housing units, 1000 qm.1)  560 non-null    object
#  23  (Rooms, number.1)                                       560 non-null    object
#  24  (Estimated costs of the construction, Tsd. EUR.1)       560 non-null    object
#  25  (Buildings / reconstruction projects, number.2)         560 non-null    object
#  26  (Buildings, number.2)                                   560 non-null    object
#  27  (Volume constructed, 1000 cbm.2)                        560 non-null    object
#  28  (Construction projects, number.2)                       560 non-null    object
#  29  (Useful floor space, 1000 qm.2)                         560 non-null    object
#  30  (Dwellings, number.2)                                   560 non-null    object
#  31  (Living floor space of dwellings, 1000 qm.2)            560 non-null    object
#  32  (Other housing units, number.2)                         560 non-null    object
#  33  (Living floor space of other housing units, 1000 qm.2)  560 non-null    object
#  34  (Rooms, number.2)                                       560 non-null    object
#  35  (Estimated costs of the construction, Tsd. EUR.2)       560 non-null    object
# dtypes: int64(1), object(35)
# memory usage: 157.6+ KB

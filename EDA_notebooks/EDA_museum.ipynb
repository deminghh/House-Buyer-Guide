# %%
import requests
import os
import pandas as pd
import json
from cred import credentials
import numpy as np

from request_api import get_genesis_api

# %%
df_museum = pd.read_csv('data/21611-0102.csv', delimiter= ';', skiprows=3, skipfooter=4, encoding = 'latin1', engine='python')
df_museum
# Out:
#                 Unnamed: 0      Unnamed: 1 Unnamed: 2   2002   2003   2004  \
# 0        Baden-Württemberg          Museen     Anzahl    830    825    821
# 1        Baden-Württemberg   Ausstellungen     Anzahl   1119   1091   1079
# 2        Baden-Württemberg  Museumsbesuche       1000  14110  12990  13600
# 3                   Bayern          Museen     Anzahl    867    876    868
# 4                   Bayern   Ausstellungen     Anzahl   1335   1311   1253
# 5                   Bayern  Museumsbesuche       1000  20454  18779  19348
# 6                   Berlin          Museen     Anzahl    128    128    125
# 7                   Berlin   Ausstellungen     Anzahl    347    343    389
# 8                   Berlin  Museumsbesuche       1000   8666   9317  11292
# 9              Brandenburg          Museen     Anzahl    265    265    263
# 10             Brandenburg   Ausstellungen     Anzahl    535    501    511
# ...

# %%
df_museum.rename(columns={'Unnamed: 0':'bundesland', 'Unnamed: 1': 'subject', 'Unnamed: 2': 'unit'}, inplace=True)
df_museum
# Out:
#                 bundesland         subject    unit   2002   2003   2004  \
# 0        Baden-Württemberg          Museen  Anzahl    830    825    821
# 1        Baden-Württemberg   Ausstellungen  Anzahl   1119   1091   1079
# 2        Baden-Württemberg  Museumsbesuche    1000  14110  12990  13600
# 3                   Bayern          Museen  Anzahl    867    876    868
# 4                   Bayern   Ausstellungen  Anzahl   1335   1311   1253
# 5                   Bayern  Museumsbesuche    1000  20454  18779  19348
# 6                   Berlin          Museen  Anzahl    128    128    125
# 7                   Berlin   Ausstellungen  Anzahl    347    343    389
# 8                   Berlin  Museumsbesuche    1000   8666   9317  11292
# 9              Brandenburg          Museen  Anzahl    265    265    263
# 10             Brandenburg   Ausstellungen  Anzahl    535    501    511
# 11             Brandenburg  Museumsbesuche    1000   3316   3592   3472
# ...

# %%
df_museum.bundesland.unique()
# Out:
# array(['Baden-Württemberg', 'Bayern', 'Berlin', 'Brandenburg', 'Bremen',
#        'Hamburg', 'Hessen', 'Mecklenburg-Vorpommern', 'Niedersachsen',
#        'Nordrhein-Westfalen', 'Rheinland-Pfalz', 'Saarland', 'Sachsen',
#        'Sachsen-Anhalt', 'Schleswig-Holstein', 'Thüringen'], dtype=object)

# %%
df_museum.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 21 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   bundesland  48 non-null     object
#  1   subject     48 non-null     object
#  2   unit        48 non-null     object
#  3   2002        48 non-null     int64
#  4   2003        48 non-null     int64
#  5   2004        48 non-null     int64
#  6   2005        48 non-null     int64
#  7   2006        48 non-null     int64
#  8   2007        48 non-null     int64
#  9   2008        48 non-null     int64
#  10  2009        48 non-null     int64
#  11  2010        48 non-null     int64
#  12  2011        48 non-null     int64
#  13  2012        48 non-null     int64
#  14  2013        48 non-null     int64
#  15  2014        48 non-null     int64
#  16  2015        48 non-null     int64
#  17  2016        48 non-null     int64
#  18  2017        48 non-null     int64
# ...

# %%
df_museum.to_csv('data/cleaned_museum.csv')

# %%
import requests
import os
import pandas as pd
import json
from cred import credentials
import numpy as np

from request_api import get_genesis_api

# %%
df_cinema = pd.read_csv('data/21611-0003.csv', delimiter= ';', decimal= ',', skiprows=5, skipfooter=4, encoding = 'latin1', engine='python')
df_cinema
# Out:
#             Unnamed: 0                              Unnamed: 1 Unnamed: 2  \
# 0    Baden-Württemberg                                   Kinos     Anzahl
# 1    Baden-Württemberg                               Leinwände     Anzahl
# 2    Baden-Württemberg                    Sitzplätze der Kinos     Anzahl
# 3    Baden-Württemberg                             Filmbesuche      Mill.
# 4    Baden-Württemberg                Filmbesuche je Einwohner     Anzahl
# ..                 ...                                     ...        ...
# 107          Thüringen                    Sitzplätze der Kinos     Anzahl
# 108          Thüringen                             Filmbesuche      Mill.
# 109          Thüringen                Filmbesuche je Einwohner     Anzahl
# 110          Thüringen  Durchschnittlicher Kino-Eintrittspreis        EUR
# 111          Thüringen      Bruttoeinnahmen aus dem Filmbesuch  Mill. EUR
#
#           2000       2001       2002      2003       2004       2005  \
# ...

# %%
df_cinema.rename(columns={'Unnamed: 0':'bundesland', 'Unnamed: 1': 'subject', 'Unnamed: 2': 'unit'}, inplace=True)
df_cinema
# Out:
#             bundesland                                 subject       unit  \
# 0    Baden-Württemberg                                   Kinos     Anzahl
# 1    Baden-Württemberg                               Leinwände     Anzahl
# 2    Baden-Württemberg                    Sitzplätze der Kinos     Anzahl
# 3    Baden-Württemberg                             Filmbesuche      Mill.
# 4    Baden-Württemberg                Filmbesuche je Einwohner     Anzahl
# ..                 ...                                     ...        ...
# 107          Thüringen                    Sitzplätze der Kinos     Anzahl
# 108          Thüringen                             Filmbesuche      Mill.
# 109          Thüringen                Filmbesuche je Einwohner     Anzahl
# 110          Thüringen  Durchschnittlicher Kino-Eintrittspreis        EUR
# 111          Thüringen      Bruttoeinnahmen aus dem Filmbesuch  Mill. EUR
#
#           2000       2001       2002      2003       2004       2005  \
# ...

# %%
df_cinema.tail(20)
# Out:
#              bundesland                                 subject       unit  \
# 92       Sachsen-Anhalt                               Leinwände     Anzahl
# 93       Sachsen-Anhalt                    Sitzplätze der Kinos     Anzahl
# 94       Sachsen-Anhalt                             Filmbesuche      Mill.
# 95       Sachsen-Anhalt                Filmbesuche je Einwohner     Anzahl
# 96       Sachsen-Anhalt  Durchschnittlicher Kino-Eintrittspreis        EUR
# 97       Sachsen-Anhalt      Bruttoeinnahmen aus dem Filmbesuch  Mill. EUR
# 98   Schleswig-Holstein                                   Kinos     Anzahl
# 99   Schleswig-Holstein                               Leinwände     Anzahl
# 100  Schleswig-Holstein                    Sitzplätze der Kinos     Anzahl
# 101  Schleswig-Holstein                             Filmbesuche      Mill.
# 102  Schleswig-Holstein                Filmbesuche je Einwohner     Anzahl
# ...

# %%
df_cinema.bundesland.nunique()
# Out:
# 16

# %%
df_cinema.to_csv('data/cleaned_cinema.csv')

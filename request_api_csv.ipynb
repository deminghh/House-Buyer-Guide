# %%
import requests
import os
import pandas as pd
from IPython.core.display import HTML
import json
from cred import credentials

# %%
# to connect to the Genesis API via data/table endpoint
de_request_url = f'https://www-genesis.destatis.de/genesisWS/rest/2020/data/table'
de_request_params = {
    'username': username,
    'password': password,
    "name": "12411-0001",
    "area": "all",
    "compress": "false",
    "transpose": "false",
    "startyear": "",
    "endyear": "",
    "timeslices": "",
    "regionalvariable": "",
    "regionalkey": "",
    "classifyingvariable1": "",
    "classifyingkey1": "",
    "classifyingvariable2": "",
    "classifyingkey2": "",
    "classifyingvariable3": "",
    "classifyingkey3": "",
    "job": "false",
    "stand": "01.01.1970",
    "language": "en" ,
}
# save the response
de_response = requests.get(url=de_request_url, params=de_request_params)
# to save the response as json in a file called "r_population.json" 
with open('data/r_population.json', 'w') as f:
    # json.dump(de_response.json(), f, indent=2)
    f.write(json.dumps(de_response.json(), indent=2))
# to save the part of response (the table) as a csv called "r_population.csv" 
with open('data/r_population.csv', 'w') as csv_file:
    csv_file.write(de_response.json()['Object']['Content'])

# %%
# request the population of the 2015-2020 for all Landcrises 
for year_diff in range(6):
    year = f'{2015 + year_diff}'
    de_request_url = f'https://www-genesis.destatis.de/genesisWS/rest/2020/data/table'
    de_request_params = {
        'username': username,
        'password': password,
        "name": "12411-0018",
        "area": "all",
        "compress": "false",
        "transpose": "false",
        "startyear": year,
        "endyear": year,
        "timeslices": "",
        "regionalvariable": "",
        "regionalkey": "",
        "classifyingvariable1": "",
        "classifyingkey1": "",
        "classifyingvariable2": "",
        "classifyingkey2": "",
        "classifyingvariable3": "",
        "classifyingkey3": "",
        "job": "false",
        "stand": "01.01.1970",
        "language": "en" ,
    }
    # to save the response as json in a file called "r_population_kries_year.json"
    de_response2 = requests.get(url=de_request_url, params=de_request_params)
    with open(f'data/r_population_kreis_{year}.json', 'w') as f2:
        json.dump(de_response2.json(), f2, indent=2)

    # to save the part of response (the table) as a csv called "r_population_kreis_year.csv" 
    with open(f'data/r_population_kreis_{year}.csv', 'w') as csv1_file:
        csv1_file.write(de_response2.json()['Object']['Content'])

# %%
# create a dictionary to convert all six csv files as data frames
dataframes = {}
for year in range(2015,2021):
    dataframes[year] = pd.read_csv(f'data/r_population_kreis_{year}.csv', skiprows=6, skipfooter=4, delimiter=';')
# Out:
# /var/folders/_k/3v2l6rmd5m3gnk2prt6lj__h0000gn/T/ipykernel_11678/2031973037.py:4: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   dataframes[year] = pd.read_csv(f'data/r_population_kreis_{year}.csv', skiprows=6, skipfooter=4, delimiter=';')
# /var/folders/_k/3v2l6rmd5m3gnk2prt6lj__h0000gn/T/ipykernel_11678/2031973037.py:4: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   dataframes[year] = pd.read_csv(f'data/r_population_kreis_{year}.csv', skiprows=6, skipfooter=4, delimiter=';')
# /var/folders/_k/3v2l6rmd5m3gnk2prt6lj__h0000gn/T/ipykernel_11678/2031973037.py:4: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
# ...

# %%
# List of the dataframes namely [dataframes[2015], dataframes[2016], dataframes[2017], dataframes[2018], dataframes[2019], dataframes[2020]] 
pdlist = [dataframes[i] for i in range(2015, 2021)] 

# to concate all dataframes in the pdlist
result_kreis_2015_2020 = pd.concat(pdlist, axis=0)
result_kreis_2015_2020
# Out:
#      Unnamed: 0  Unnamed: 1                      Unnamed: 2 under 3 years  \
# 0    2015-12-31        1001     Flensburg, kreisfreie Stadt          1143
# 1    2015-12-31        1002          Kiel, kreisfreie Stadt          3412
# 2    2015-12-31        1003        Lübeck, kreisfreie Stadt          2887
# 3    2015-12-31        1004    Neumünster, kreisfreie Stadt           985
# 4    2015-12-31        1051         Dithmarschen, Landkreis          1532
# ..          ...         ...                             ...           ...
# 471  2020-12-31       16073  Saalfeld-Rudolstadt, Landkreis          1114
# 472  2020-12-31       16074            Saale-Holzland-Kreis           900
# 473  2020-12-31       16075                Saale-Orla-Kreis           907
# 474  2020-12-31       16076                Greiz, Landkreis          1020
# 475  2020-12-31       16077     Altenburger Land, Landkreis           907
#
#     3 to under 6 years 6 to under 10 years 10 to under 15 years  \
# ...

# %%
# convert the result data frame of all years to CSV again
result_kreis_2015_2020.to_csv(r'population_kreis_2015_2020.csv', index=False)
